# %% [markdown]
# <Center>
#     <h1 style="font-family: Roboto slab">
#         <p>
#         <font color="white">
#             Sentiment Mining for Amazon Devices:
#             <br>
#             Applying Natural Language Processing with Machine Learning and Deep Learning Techniques
#         </font>
#     </h1>
#     <h3 style="font-family: Roboto slab">
#         <font color="yellow">
#             Notebook 1/5: Web Scraping
#         </font>
#     </h3>
# </Center>

# %% [markdown]
# # I. Introduction & Context
# ---------------------------------------------------------------------------

# %% [markdown]
# ### <font color = "yellow" >Objective:</font>
# This project aims to build a sentiment analysis tool to classify customer reviews of Amazon devices as positive, negative, or neutral. <br>
#
# The project involves preprocessing review text, extracting key features, and implementing both traditional machine learning models (Logistic Regression, Naive Bayes, Support Vector Machines, ...) and deep learning models (LSTM-based RNNs). After training and evaluating these models, the project will compare their performance to select the most effective one for deployment in the sentiment analysis tool. This approach ensures that the tool utilizes the best-performing model to deliver accurate sentiment classification, ultimately supporting better business decisions and product improvements.
#
# ### <font color = "yellow">Application Overview:</font>
# This application approach is divided into 5 core steps:
#
# <ul>
#     <li>
#         <u>Step 1:</u>  Data Collection
#         <ul>
#             <li> <b>Description:</b> Gather Amazon devices reviews from Amazon's website using web scraping techniques: Selenium, BeautifulSoup, scrape review data to capture review_id, Reviewer, Rating, Date, Review_title, Review_content, Product_id & Product_link</li>
#             <li> <b> Output: </b> Raw dataset of Amazon device reviews, including review text, star ratings, and other relevant metadata.</li>
#         </ul>
#     </li>
# </ul>
# <ul>
#     <li>
#         <u>Step 2:</u> Data Pre-Processing
#         <ul>
#             <li><b> Description: </b> Clean and prepare the review text for exploratory analysis. Identify and resolve missing values or inconsistencies in the dataset. Convert text to lowercase, remove special characters, stop words, punctuations; apply tokenization and lemmatization.
#             </li>
#             <li> <b> Output: </b> Cleaned dataset for EDA and model development.</li>
#         </ul>
#     </li>
# </ul>
# <ul>
#     <li>
#         <u>Step 3:</u> Exploratory Data Analysis
#         <ul>
#             <li>Data Distribution: Analyze review counts across sentiment classes. </li>
#             <li>Text Analysis: Review text length, word count, and common words.</li>
#             <li>Sentiment Visualization: Visualize trends in positive, neutral, and negative reviews.</li>
#         </ul>
#     </li>
# </ul>
# <ul>
#     <li>
#         <u>Step 4:</u > Model Development
#          <ul>
#             <li>Developing 5 machine learning and LSTM deep learning models.</li>
#             <li>Evaluating models performance.</li>
#             <li>Selecting the best model for final hyperparameter tuning</li>
#             <li>Validating final model's predictions on 10 new real reviews</li>
#         </ul>
#     </li>
# </ul>
# <ul>
#     <li>
#         <u>Step 5:</u> Model Deployment
#         <ul>
#             <li>Deploy the sentiment analysis model via a Flask API and create a website for users to input reviews and view predicted sentiments in real-time.</li>
#         </ul>
#     </li>
# </ul>

# %% [markdown]
# # II. Amazon Web Scraping
# ---------------------------------------------------------------------------

# %% [markdown]
# ## <font color = "red">1.  Web Scraping Tools: Selenium and BeautifulSoup</font>

# %% [markdown]
# - <b>Selenium:</b> is a web automation tool primarily used for testing web applications. In this project, Selenium automates the process of navigating through Amazon’s web pages, handling actions like clicking the "Next" button to move through multiple review pages, accepting cookies or other pop-ups, and interacting with JavaScript elements to load reviews dynamically. This ensures that all reviews are fully loaded and accessible for scraping, especially those that might not initially appear on the page without user interaction.<bf>
#
# - <b>BeautifulSoup: </b> is a Python library designed for parsing HTML and XML documents. After Selenium has loaded a web page, BeautifulSoup helps in navigating and extracting specific data elements from the page structure. It simplifies the process of locating data by offering easy-to-use methods for accessing tags, attributes, and text content, making it ideal for structuring the extracted data from web scraping tasks.

# %% [markdown]
# ## <font color = "red">2.  Libaries Import</font>

# %%
import pandas as pd
from datetime import datetime

from urllib.parse import unquote, urlparse, parse_qs
from bs4 import BeautifulSoup

# Selenium libraries
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
import time
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By

# %% [markdown]
# ## <font color="red">3.  Function initialization</font>

# %%
def generate_review_link(page_no, product_path, product_id):
    """
    Function that generates one review page url for each product

    Parameters
    ----------
    page_no : review page number
    product_path: product name path
    product_id: product id

    Returns
    -------
    str: review page url

    """
    return (f"https://www.amazon.com/{product_path}/product-reviews/{product_id}"
            f"/ref=cm_cr_arp_d_paging_btm_next_{page_no}?ie=UTF8&reviewerType=all_reviews&pageNumber={page_no}")

# %%
def normalize_url(url):
    """
    Function that normalizes product url to direct link

    Parameters
    ----------
    url: original url extracted from web page

    Returns
    -------
    str: normalized product url

    """
    
    if "/sspa/click" in url:   # Check if the URL is a sponsored link (Type 1)   
        parsed_url = urlparse(url)    # Extract the 'url' parameter from the query string
        query_params = parse_qs(parsed_url.query)

        if 'url' in query_params:
            product_url = unquote(query_params['url'][0])   # Decode the product path URL from the 'url' parameter
            return product_url
    
    # ElseIf it's already a direct product link (Type 2), return it as is
    return url

# %%
# Initialize the ChromeDriver service for Selenium 
webdriver_service = Service("/usr/local/bin/chromedriver")

# Set Chrome options
chrome_options = Options()
chrome_options.add_argument("--no-sandbox")
chrome_options.add_experimental_option("detach", True)
chrome_options.add_argument("--disable-dev-shm-usage")
chrome_options.add_argument("--disable-blink-features=AutomationControlled")  # Avoid detection
chrome_options.add_argument("user-agent=Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_7")

# Create a new Chrome browser instance
driver = webdriver.Chrome(service=webdriver_service, options=chrome_options)

# %%
def getAllHtml (products_page_len):
    """
    Function that uses Selenium and BeautifulSoup to scrape the web page and parse it to html format

    Parameters
    ----------
    products_page_len: number of product pages to scrape

    Returns
    -------
    list: list of dictionnaries for all reviews and BeautifulSoup objects

    """

    # Initialize an empty list to hold BeautifulSoup objects
    soups = []

    #///////////////////////////////////////////#
    # Outer Loop: Navigating Product List Pages #
    #///////////////////////////////////////////#

    for page_no in range(1, products_page_len + 1):
         
        URL = f"https://www.amazon.com/s?i=amazon-devices&rh=n%3A2102313011&s=popularity-rank&fs=true&page={page_no}&qid=1729958028&ref=sr_pg_{page_no}"   # List of products pages to scrape

        driver.get(URL)  # Load each product list page
        driver.maximize_window()
        time.sleep(5) # Wait for content to load fully

        # Locating and Extracting Product Divs
        driver.find_elements(By.CSS_SELECTOR, 'div[data-component-type="s-search-result"]')  # Finds multiple elements matching the CSS selector, each representing a product <div>.
        time.sleep(2)

        product_list = BeautifulSoup(driver.page_source, 'html.parser') 
        product_divs = product_list.find_all('div', attrs={'data-component-type': "s-search-result"})  # Find all <div> elements with the 'data-component-type' attribute
  

        print(f"Page {page_no}: {URL}")
        print(f"--> There are: {len(product_divs)} products")

        if not product_divs: # Exit the loop and finish the function when it comes to last page which has no products
            break
        else: 
            #///////////////////////////////////////////#
            # Loop through all product divs of each page #
            #///////////////////////////////////////////#
            count = 0
            for div in product_divs:

                count = count + 1

                link_html = div.find("a", attrs={'class':'a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal'})                  # Find the <a> tag within the current <div>
                link = normalize_url(link_html.get('href'))
                product_title = div.find("span", attrs={'class': 'a-size-medium a-color-base a-text-normal'}).get_text(strip=True)  # Extract product title

                path_parts = urlparse(link).path.split('/') # Extract the 'url' parameter contains the final product path

                
                product_path = path_parts[1]  # Extract the product path, example: 'Android-Expanded-Quad-core-processor-certified'
                product_id = path_parts[3]  # # Extract the product ID, example: 'B0D6279VW5'
                product_url = f"https://www.amazon.com{link}"

            
                #////////////////////////////////////////////////////#
                # Loop through list of review pages for Each Product#
                #///////////////////////////////////////////////////#
                print(f"Page {page_no}, product {count} : {product_title}")

                for i in range(1, 11):  # Amazon only allows to show 10 pages of reviews

                    review_link = generate_review_link(i, product_path, product_id)  # Call generate_review_link function to generate link for each review list page
                    
                    driver.get(review_link)  #Load each review page
                    time.sleep(5)  # Wait for content to load

                    review_divs = driver.find_elements(By.CSS_SELECTOR, 'div[data-hook="review"]')  # Find elements that contain review details
                    time.sleep(2)

                    soup = BeautifulSoup(driver.page_source, 'html.parser')

                    if not review_divs: # exit this loop when it comes to the last page of reviews and move to next product
                        print("no review divs")
                        break

                    else:
                        print(f"Review page {i}: There are {len(review_divs)} reviews")  
                        # Add single Html product review data in master soups list
                        soup_dict = {
                            "product_id": product_id,
                            "product_title": product_title,
                            "product_url": product_url,
                            "review_data": soup
                        }
                        soups.append(soup_dict)

    driver.quit()
    
    return soups

# %%
def getReviews(review_dict):
    """
    Function that extract scraped Html content to review details

    Parameters
    ----------
    list : list of BeautifulSoup objects

    Returns
    -------
    list : list of dictionaries of reviews: review_id, reviewer name, rating, date, review title, review content, product id, product title, product link

    """

    data_dicts = []  # Create Empty list to Hold all Reviews
    html_product = review_dict["review_data"]
    
    boxes = html_product.select('div[data-hook="review"]')  # Select all Reviews BOX html using css selector
    
    
    #////////////////////////////////////////////////////#
    # Loop through all the reviews///////////////////////#
    #///////////////////////////////////////////////////#
    for box in boxes:
        
        try:
            name = box.select_one('[class="a-profile-name"]').text.strip()   # Select Name using css selector and cleaning text using strip()
        except Exception as e:
            name = 'N/A'    # If Value is empty define value with 'N/A' for all.

        try:
            rating = box.select_one('[data-hook="review-star-rating"]').text.strip().split(' out')[0]
        except Exception as e:
            rating = 'N/A' 

        try:
            review_id = box.get('id')
        except Exception as e:
            review_id = 'N/A'  

        try:
            review_title = box.select_one('[data-hook="review-title"]').text.strip().split('\n')[1]
        except Exception as e:
            review_title = 'N/A'

        try:
            # Convert date str to dd/mm/yyy format
            datetime_str = box.select_one('[data-hook="review-date"]').text.strip().split(' on ')[1]
            review_date = datetime.strptime(datetime_str, '%B %d, %Y').strftime("%d/%m/%Y")
        except Exception as e:
            review_date = 'N/A'

        try:
            review_content = box.select_one('[data-hook="review-body"]').text.strip()
        except Exception as e:
            review_content = 'N/A'

        # create Dictionary with all for all reviews 
        data_dict = {
            'Review_id': review_id,
            'Reviewer': name,
            'Rating': rating,
            'Date': review_date,
            'Review title': review_title,
            'Review content': review_content,
            'Product_id': review_dict["product_id"],
            'Product_title': review_dict["product_title"],
            'Product_link': review_dict["product_url"]
        }

        # Add Dictionary in master empty List
        data_dicts.append(data_dict)
    
    return data_dicts

# %% [markdown]
# ## <font color="red">4. Function application & Data Processing</font>

# %%
#Grab all HTML data: 29 existing pages of Amazon Devices
html_datas = getAllHtml(29)
# Out:
# Page 1: https://www.amazon.com/s?i=amazon-devices&rh=n%3A2102313011&s=popularity-rank&fs=true&page=1&qid=1729958028&ref=sr_pg_1
# --> There are: 24 products
# Page 1, product 1 : Blink Subscription Plus Plan with monthly auto-renewal
# Review page 1: There are 10 reviews
# Review page 2: There are 10 reviews
# Review page 3: There are 10 reviews
# Review page 4: There are 10 reviews
# Review page 5: There are 10 reviews
# Review page 6: There are 10 reviews
# Review page 7: There are 10 reviews
# Review page 8: There are 10 reviews
# Review page 9: There are 10 reviews
# Review page 10: There are 10 reviews
# Page 1, product 2 : Amazon Fire TV Stick 4K with AI-powered Fire TV Search, Wi-Fi 6, stream over 1.5 million movies and shows, free & live TV
# Review page 1: There are 10 reviews
# Review page 2: There are 10 reviews
# Review page 3: There are 10 reviews
# Review page 4: There are 10 reviews
# Review page 5: There are 10 reviews
# Review page 6: There are 10 reviews
# Review page 7: There are 10 reviews
# Review page 8: There are 10 reviews
# Review page 9: There are 10 reviews
# Review page 10: There are 10 reviews
# Page 1, product 3 : All-new Ring Battery Doorbell — Now with 66% more coverage, Head-to-Toe Video, Live View with Two-Way Talk, and Motion Detection & Alerts (2024 release), Venetian Bronze
# Review page 1: There are 10 reviews
# Review page 2: There are 10 reviews
# Review page 3: There are 10 reviews
# Review page 4: There are 10 reviews
# Review page 5: There are 10 reviews
# Review page 6: There are 10 reviews
# Review page 7: There are 10 reviews
# Review page 8: There are 10 reviews
# Review page 9: There are 10 reviews
# Review page 10: There are 10 reviews
# Page 1, product 4 : All-new Amazon Kindle Paperwhite (16 GB) – Our fastest Kindle ever, with new 7" glare-free display and weeks of battery life – Black
# Review page 1: There are 10 reviews
# Review page 2: There are 10 reviews
# Review page 3: There are 10 reviews
# Review page 4: There are 10 reviews
# Review page 5: There are 10 reviews
# Review page 6: There are 10 reviews
# Review page 7: There are 10 reviews
# Review page 8: There are 10 reviews
# Review page 9: There are 10 reviews
# Review page 10: There are 10 reviews
# Page 1, product 5 : New Amazon Kindle (16 GB) - Lightest and most compact Kindle, with glare-free display, faster page turns, adjustable front light, and long battery life - Matcha
# Review page 1: There are 10 reviews
# Review page 2: There are 10 reviews
# Review page 3: There are 10 reviews
# Review page 4: There are 10 reviews
# Review page 5: There are 10 reviews
# Review page 6: There are 10 reviews
# Review page 7: There are 10 reviews
# Review page 8: There are 10 reviews
# Review page 9: There are 6 reviews
# no review divs
# Page 1, product 6 : Blink Video Doorbell | Two-way audio, HD video, motion and chime app alerts and Alexa enabled — wired or wire-free (Black)
# Review page 1: There are 10 reviews
# Review page 2: There are 10 reviews
# Review page 3: There are 10 reviews
# Review page 4: There are 10 reviews
# Review page 5: There are 10 reviews
# Review page 6: There are 10 reviews
# Review page 7: There are 10 reviews
# Review page 8: There are 10 reviews
# Review page 9: There are 10 reviews
# Review page 10: There are 10 reviews
# Page 1, product 7 : All-new Amazon Kindle Paperwhite Signature Edition (32 GB) – Our fastest Kindle with auto-adjusting front light, wireless charging, and weeks of battery life – Metallic Black
# Review page 1: There are 10 reviews
# Review page 2: There are 10 reviews
# Review page 3: There are 10 reviews
# Review page 4: There are 10 reviews
# Review page 5: There are 10 reviews
# Review page 6: There are 10 reviews
# Review page 7: There are 10 reviews
# Review page 8: There are 4 reviews
# no review divs
# Page 1, product 8 : Amazon Fire TV Stick HD, free and live TV, Alexa Voice Remote, smart home controls, HD streaming
# Review page 1: There are 10 reviews
# Review page 2: There are 5 reviews
# no review divs
# Page 1, product 9 : Blink Video Doorbell + 3 Outdoor 4 smart security cameras (4th Gen) with Sync Module 2 | Two-year battery life, motion detection, two-way audio, HD video, Works with Alexa
# Review page 1: There are 10 reviews
# Review page 2: There are 10 reviews
# Review page 3: There are 10 reviews
# Review page 4: There are 10 reviews
# Review page 5: There are 10 reviews
# Review page 6: There are 10 reviews
# Review page 7: There are 10 reviews
# Review page 8: There are 10 reviews
# Review page 9: There are 10 reviews
# Review page 10: There are 10 reviews
# Page 1, product 10 : All-new Ring No-Drill Mount for Battery Doorbell
# Review page 1: There are 10 reviews
# Review page 2: There are 10 reviews
# Review page 3: There are 10 reviews
# Review page 4: There are 10 reviews
# Review page 5: There are 10 reviews
# Review page 6: There are 10 reviews
# Review page 7: There are 10 reviews
# Review page 8: There are 10 reviews
# Review page 9: There are 10 reviews
# Review page 10: There are 10 reviews
# Page 1, product 11 : Echo Pop Charcoal with Amazon Smart Plug
# Review page 1: There are 10 reviews
# Review page 2: There are 10 reviews
# Review page 3: There are 10 reviews
# Review page 4: There are 8 reviews
# no review divs
# Page 1, product 12 : Blink Outdoor 4 (4th Gen) + Blink Mini – Smart security camera, two-way talk, HD live view, motion detection, set up in minutes, Works with Alexa – 6 camera system + Mini (Black)
# Review page 1: There are 10 reviews
# Review page 2: There are 10 reviews
# Review page 3: There are 10 reviews
# Review page 4: There are 10 reviews
# Review page 5: There are 10 reviews
# Review page 6: There are 10 reviews
# Review page 7: There are 10 reviews
# Review page 8: There are 10 reviews
# Review page 9: There are 10 reviews
# Review page 10: There are 10 reviews
# Page 1, product 13 : New Amazon Fire HD 8 tablet, 8” HD Display, 3GB memory, 32GB, designed for portable entertainment, Black, (2024 release)
# Review page 1: There are 10 reviews
# Review page 2: There are 10 reviews
# Review page 3: There are 10 reviews
# Review page 4: There are 10 reviews
# Review page 5: There are 7 reviews
# no review divs
# Page 1, product 14 : Blink Mini 2 — Plug-in smart security camera, HD night view in color, built-in spotlight, two-way audio, motion detection, Works with Alexa (White)
# Review page 1: There are 10 reviews
# Review page 2: There are 10 reviews
# Review page 3: There are 10 reviews
# Review page 4: There are 10 reviews
# Review page 5: There are 10 reviews
# Review page 6: There are 10 reviews
# Review page 7: There are 10 reviews
# Review page 8: There are 10 reviews
# Review page 9: There are 10 reviews
# Review page 10: There are 10 reviews
# Page 1, product 15 : Echo Dot with TP-Link Tapo Smart Color Bulb
# Review page 1: There are 10 reviews
# Review page 2: There are 10 reviews
# Review page 3: There are 10 reviews
# Review page 4: There are 3 reviews
# no review divs
# Page 1, product 16 : Kindle Scribe Essentials Bundle including Kindle Scribe (16 GB), Basic Pen, Leather Folio Cover with Magnetic Attach - Burgundy, and Power Adapter
# Review page 1: There are 10 reviews
# Review page 2: There are 10 reviews
# Review page 3: There are 10 reviews
# Review page 4: There are 10 reviews
# Review page 5: There are 10 reviews
# Review page 6: There are 10 reviews
# Review page 7: There are 10 reviews
# Review page 8: There are 10 reviews
# Review page 9: There are 10 reviews
# Review page 10: There are 10 reviews
# Page 1, product 17 : Ring Spotlight Cam Plus, Solar | Two-Way Talk, Color Night Vision, and Security Siren (2022 release) - White
# Review page 1: There are 10 reviews
# Review page 2: There are 10 reviews
# Review page 3: There are 10 reviews
# Review page 4: There are 10 reviews
# Review page 5: There are 10 reviews
# Review page 6: There are 10 reviews
# Review page 7: There are 10 reviews
# Review page 8: There are 10 reviews
# Review page 9: There are 10 reviews
# Review page 10: There are 10 reviews
# Page 1, product 18 : TCL 40-Inch Class S3 1080p LED Smart TV with Fire TV (40S350F, 2023 Model), Alexa Built-in, Apple AirPlay Compatibility, Streaming FHD Television,Black
# Review page 1: There are 10 reviews
# Review page 2: There are 10 reviews
# Review page 3: There are 10 reviews
# Review page 4: There are 10 reviews
# Review page 5: There are 10 reviews
# Review page 6: There are 10 reviews
# Review page 7: There are 10 reviews
# Review page 8: There are 10 reviews
# Review page 9: There are 10 reviews
# Review page 10: There are 10 reviews
# Page 1, product 19 : Ring Floodlight Cam Wired Pro with Bird’s Eye View and 3D Motion Detection, Black
# Review page 1: There are 10 reviews
# Review page 2: There are 10 reviews
# Review page 3: There are 10 reviews
# Review page 4: There are 10 reviews
# Review page 5: There are 10 reviews
# Review page 6: There are 10 reviews
# Review page 7: There are 10 reviews
# Review page 8: There are 10 reviews
# Review page 9: There are 10 reviews
# Review page 10: There are 10 reviews
# Page 1, product 20 : Blink Wired Floodlight Camera – Smart security camera, 2600 lumens, HD live view, enhanced motion detection, built-in siren, Works with Alexa – 1 camera (White)
# Review page 1: There are 10 reviews
# Review page 2: There are 10 reviews
# Review page 3: There are 10 reviews
# Review page 4: There are 10 reviews
# Review page 5: There are 10 reviews
# Review page 6: There are 10 reviews
# Review page 7: There are 10 reviews
# Review page 8: There are 10 reviews
# Review page 9: There are 10 reviews
# Review page 10: There are 10 reviews
# Page 1, product 21 : Amazon Echo Studio | Our best-sounding smart speaker ever - With Dolby Atmos, spatial audio processing technology, and Alexa | Charcoal
# Review page 1: There are 10 reviews
# Review page 2: There are 10 reviews
# Review page 3: There are 10 reviews
# Review page 4: There are 10 reviews
# Review page 5: There are 10 reviews
# Review page 6: There are 10 reviews
# Review page 7: There are 10 reviews
# Review page 8: There are 10 reviews
# Review page 9: There are 10 reviews
# Review page 10: There are 10 reviews
# Page 1, product 22 : Echo Spot with TP-Link Tapo Smart Color Bulb
# Review page 1: There are 10 reviews
# Review page 2: There are 7 reviews
# no review divs
# Page 1, product 23 : Amazon Fire TV Stick 4K with USB Power Cable (eliminates the need for AC adapter)
# Review page 1: There are 4 reviews
# no review divs
# Page 1, product 24 : Blink Outdoor 4 one-camera system + Amazon Echo Show 5
# Review page 1: There are 6 reviews
# no review divs
# Page 2: https://www.amazon.com/s?i=amazon-devices&rh=n%3A2102313011&s=popularity-rank&fs=true&page=2&qid=1729958028&ref=sr_pg_2
# --> There are: 24 products
# Page 2, product 1 : Ring Stick Up Cam Solar | Weather-Resistant Outdoor Camera, Live View, Color Night Vision, Two-way Talk, Motion alerts, Works with Alexa | White
# Review page 1: There are 10 reviews
# Review page 2: There are 10 reviews
# Review page 3: There are 10 reviews
# Review page 4: There are 10 reviews
# Review page 5: There are 10 reviews
# Review page 6: There are 10 reviews
# Review page 7: There are 10 reviews
# Review page 8: There are 10 reviews
# Review page 9: There are 10 reviews
# Review page 10: There are 10 reviews
# Page 2, product 2 : Ring Battery Doorbell with Ring Chime
# Review page 1: There are 8 reviews
# no review divs
# Page 2, product 3 : Echo Pop with TP-Link Tapo Smart Color Bulb
# Review page 1: There are 10 reviews
# Review page 2: There are 10 reviews
# Review page 3: There are 10 reviews
# Review page 4: There are 8 reviews
# no review divs
# Page 2, product 4 : Amazon Fire TV Stick 4K with USB Power Cable (eliminates the need for AC adapter)
# Review page 1: There are 4 reviews
# no review divs
# Page 2, product 5 : Certified Refurbished Blink Outdoor 4 (4th Gen) – Wire-free smart security camera, two-year battery life, two-way audio, HD live view, enhanced motion detection, Works with Alexa – 2 camera system
# Review page 1: There are 10 reviews
# Review page 2: There are 10 reviews
# Review page 3: There are 1 reviews
# no review divs
# Page 2, product 6 : Blink Whole Home Bundle – Outdoor 4 camera, Mini 2 camera (white), Video Doorbell system (black) | HD video, motion detection, Works with Alexa
# Review page 1: There are 10 reviews
# Review page 2: There are 10 reviews
# Review page 3: There are 10 reviews
# Review page 4: There are 10 reviews
# Review page 5: There are 10 reviews
# Review page 6: There are 10 reviews
# Review page 7: There are 8 reviews
# no review divs
# Page 2, product 7 : Amazon Fire TV 55" Omni QLED Series 4K UHD smart TV, Dolby Vision IQ, Fire TV Ambient Experience, local dimming, hands-free with Alexa
# Review page 1: There are 10 reviews
# Review page 2: There are 10 reviews
# Review page 3: There are 10 reviews
# Review page 4: There are 10 reviews
# Review page 5: There are 10 reviews
# Review page 6: There are 10 reviews
# Review page 7: There are 10 reviews
# Review page 8: There are 10 reviews
# Review page 9: There are 10 reviews
# Review page 10: There are 10 reviews
# Page 2, product 8 : Amazon Fire Max 11 tablet (newest model) vivid 11” display, all-in-one for streaming, reading, and gaming, 14-hour battery life, optional stylus and keyboard, 64 GB, Gray, without lockscreen ads
# Review page 1: There are 10 reviews
# Review page 2: There are 10 reviews
# Review page 3: There are 10 reviews
# Review page 4: There are 10 reviews
# Review page 5: There are 10 reviews
# Review page 6: There are 10 reviews
# Review page 7: There are 10 reviews
# Review page 8: There are 10 reviews
# Review page 9: There are 10 reviews
# Review page 10: There are 10 reviews
# Page 2, product 9 : Amazon Fire HD 10 tablet (newest model) built for relaxation, 10.1" vibrant Full HD screen, octa-core processor, 3 GB RAM, 32 GB, Black, without lockscreen ads
# Review page 1: There are 10 reviews
# Review page 2: There are 10 reviews
# Review page 3: There are 10 reviews
# Review page 4: There are 10 reviews
# Review page 5: There are 10 reviews
# Review page 6: There are 10 reviews
# Review page 7: There are 10 reviews
# Review page 8: There are 10 reviews
# Review page 9: There are 10 reviews
# Review page 10: There are 10 reviews
# Page 2, product 10 : Blink Outdoor 4 + Blink Mini 2 — Smart security cameras, two-way talk, HD live view, motion detection, set up in minutes, Works with Alexa — 3 camera system + Mini 2 (Black)
# Review page 1: There are 10 reviews
# Review page 2: There are 10 reviews
# Review page 3: There are 10 reviews
# Review page 4: There are 10 reviews
# Review page 5: There are 10 reviews
# Review page 6: There are 10 reviews
# Review page 7: There are 10 reviews
# Review page 8: There are 8 reviews
# no review divs
# Page 2, product 11 : Amazon eero Pro 6E mesh Wi-Fi System | Fast and reliable gigabit + speeds | connect 100+ devices | Coverage up to 8,000 sq. ft. | 4-pack, 2022 release
# Review page 1: There are 10 reviews
# Review page 2: There are 10 reviews
# Review page 3: There are 10 reviews
# Review page 4: There are 10 reviews
# Review page 5: There are 10 reviews
# Review page 6: There are 10 reviews
# Review page 7: There are 10 reviews
# Review page 8: There are 10 reviews
# Review page 9: There are 10 reviews
# Review page 10: There are 10 reviews
# Page 2, product 12 : Ring Video Doorbell Wired with Ring Chime
# Review page 1: There are 10 reviews
# Review page 2: There are 10 reviews
# Review page 3: There are 10 reviews
# Review page 4: There are 10 reviews
# Review page 5: There are 10 reviews
# Review page 6: There are 10 reviews
# Review page 7: There are 10 reviews
# Review page 8: There are 10 reviews
# Review page 9: There are 10 reviews
# Review page 10: There are 10 reviews
# Page 2, product 13 : 2 Packs USB C Headphones for iPhone 15 Type C Earbuds Wired Earphones with Mic & Remote Control Noise Cancelling for iPhone 15 pro, iPad Pro, Galaxy S23/S22/S21/S20/Ultra Note 10/20, Pixel 7/6/6a/5/4
# Review page 1: There are 10 reviews
# Review page 2: There are 10 reviews
# Review page 3: There are 10 reviews
# Review page 4: There are 10 reviews
# Review page 5: There are 10 reviews
# Review page 6: There are 10 reviews
# Review page 7: There are 10 reviews
# Review page 8: There are 10 reviews
# Review page 9: There are 10 reviews
# Review page 10: There are 10 reviews
# Page 2, product 14 : Made for Amazon, Wireless Charging Dock for Kindle Paperwhite Signature Edition. Only compatible with Kindle Paperwhite Signature Edition (2022 Release)
# Review page 1: There are 10 reviews
# Review page 2: There are 10 reviews
# Review page 3: There are 10 reviews
# Review page 4: There are 10 reviews
# Review page 5: There are 10 reviews
# Review page 6: There are 10 reviews
# Review page 7: There are 10 reviews
# Review page 8: There are 10 reviews
# Review page 9: There are 10 reviews
# Review page 10: There are 10 reviews
# Page 2, product 15 : Blink Mini – Compact indoor plug-in smart security camera, 1080p HD video, night vision, motion detection, two-way audio, easy set up, Works with Alexa – 3 cameras (White)
# Review page 1: There are 10 reviews
# Review page 2: There are 10 reviews
# Review page 3: There are 10 reviews
# Review page 4: There are 10 reviews
# Review page 5: There are 10 reviews
# Review page 6: There are 10 reviews
# Review page 7: There are 10 reviews
# Review page 8: There are 10 reviews
# Review page 9: There are 10 reviews
# Review page 10: There are 10 reviews
# Page 2, product 16 : Ring Floodlight Cam Wired Plus with motion-activated 1080p HD video (2021 release), 2-pack, White
# Review page 1: There are 10 reviews
# Review page 2: There are 10 reviews
# Review page 3: There are 10 reviews
# Review page 4: There are 10 reviews
# Review page 5: There are 10 reviews
# Review page 6: There are 10 reviews
# Review page 7: There are 10 reviews
# Review page 8: There are 10 reviews
# Review page 9: There are 10 reviews
# Review page 10: There are 10 reviews
# Page 2, product 17 : Amazon Fire TV Stick 4K Max with USB Power Cable (eliminates the need for AC adapter)
# Review page 1: There are 10 reviews
# Review page 2: There are 10 reviews
# Review page 3: There are 10 reviews
# Review page 4: There are 10 reviews
# Review page 5: There are 10 reviews
# Review page 6: There are 10 reviews
# Review page 7: There are 10 reviews
# Review page 8: There are 10 reviews
# Review page 9: There are 10 reviews
# Review page 10: There are 10 reviews
# Page 2, product 18 : Echo Show 8 with TP-Link Tapo Smart Color Bulb
# Review page 1: There are 9 reviews
# no review divs
# Page 2, product 19 : Ring Indoor Cam (2nd Gen) | latest generation, 2023 release | 1080p HD Video & Color Night Vision, Two-Way Talk, and Manual Audio & Video Privacy Cover | Starlight
# Review page 1: There are 10 reviews
# Review page 2: There are 10 reviews
# Review page 3: There are 10 reviews
# Review page 4: There are 10 reviews
# Review page 5: There are 10 reviews
# Review page 6: There are 10 reviews
# Review page 7: There are 10 reviews
# Review page 8: There are 10 reviews
# Review page 9: There are 10 reviews
# Review page 10: There are 10 reviews
# Page 2, product 20 : New Amazon Kindle Scribe Essentials Bundle including New Kindle Scribe (64GB) - Metallic Jade, Premium Pen, Plant-Based Leather Folio-Jade, and Power Adapter
# no review divs
# Page 2, product 21 : New Amazon Kindle Kids (16 GB) - If it breaks, we will replace it, includes ad-free books and cover, with glare-free display, faster page turns - Space Whale
# Review page 1: There are 3 reviews
# no review divs
# Page 2, product 22 : Kindle Scribe Essentials Bundle including Kindle Scribe (16 GB), Basic Pen, Brush Print Leather Folio Cover with Magnetic Attach - Storm Grey, and Power Adapter
# Review page 1: There are 10 reviews
# Review page 2: There are 10 reviews
# Review page 3: There are 10 reviews
# Review page 4: There are 10 reviews
# Review page 5: There are 10 reviews
# Review page 6: There are 1 reviews
# no review divs
# Page 2, product 23 : Certified Refurbished Ring Stick Up Cam Battery HD security camera with custom privacy controls, Simple setup, Works with Alexa - White
# Review page 1: There are 10 reviews
# Review page 2: There are 10 reviews
# Review page 3: There are 10 reviews
# Review page 4: There are 10 reviews
# Review page 5: There are 10 reviews
# Review page 6: There are 10 reviews
# Review page 7: There are 10 reviews
# Review page 8: There are 10 reviews
# Review page 9: There are 10 reviews
# Review page 10: There are 10 reviews
# Page 2, product 24 : Amazon eero mesh wifi system—router replacement for whole-home coverage (3-pack)
# Review page 1: There are 10 reviews
# Review page 2: There are 10 reviews
# Review page 3: There are 10 reviews
# Review page 4: There are 10 reviews
# Review page 5: There are 10 reviews
# Review page 6: There are 10 reviews
# Review page 7: There are 10 reviews
# Review page 8: There are 10 reviews
# Review page 9: There are 10 reviews
# Review page 10: There are 10 reviews
# Page 3: https://www.amazon.com/s?i=amazon-devices&rh=n%3A2102313011&s=popularity-rank&fs=true&page=3&qid=1729958028&ref=sr_pg_3
# --> There are: 24 products
# Page 3, product 1 : Ring Battery Doorbell with Ring Floodlight Cam Wired Plus (White)
# no review divs
# Page 3, product 2 : Amazon eero mesh wifi system—router replacement for whole-home coverage (3-pack)
# Review page 1: There are 10 reviews
# Review page 2: There are 10 reviews
# Review page 3: There are 10 reviews
# Review page 4: There are 10 reviews
# Review page 5: There are 10 reviews
# Review page 6: There are 10 reviews
# Review page 7: There are 10 reviews
# Review page 8: There are 10 reviews
# Review page 9: There are 10 reviews
# Review page 10: There are 10 reviews
# Page 3, product 3 : Ring Battery Doorbell with Ring Indoor Cam 2nd Gen (White)
# no review divs
# Page 3, product 4 : Echo Spot Bundle: Includes Echo Spot (2024 Release) | Black & Made for Amazon Stand with USB-C and USB-A Charging Ports | Black
# Review page 1: There are 10 reviews
# Review page 2: There are 10 reviews
# Review page 3: There are 10 reviews
# Review page 4: There are 6 reviews
# no review divs
# Page 3, product 5 : New Amazon Fire HD 8 Kids tablet, ages 3-7 | 3GB memory, ad-free content with parental controls included, 13-hr battery, 32GB, Grape, (2024 release)
# Review page 1: There are 6 reviews
# no review divs
# Page 3, product 6 : Introducing Ring Pan-Tilt Indoor Cam | See all around with 360° pan coverage, HD video, plus Two-Way Talk (2024 release) | 2-Pack, White
# Review page 1: There are 10 reviews
# Review page 2: There are 10 reviews
# Review page 3: There are 10 reviews
# Review page 4: There are 10 reviews
# Review page 5: There are 10 reviews
# Review page 6: There are 10 reviews
# Review page 7: There are 10 reviews
# Review page 8: There are 10 reviews
# Review page 9: There are 10 reviews
# Review page 10: There are 10 reviews
# Page 3, product 7 : Ring Battery Doorbell with Ring Stick Up Cam Battery (White)
# Review page 1: There are 1 reviews
# no review divs
# Page 3, product 8 : Ring Battery Doorbell Plus with Ring Stick Up Cam Battery, White
# Review page 1: There are 10 reviews
# Review page 2: There are 9 reviews
# no review divs
# Page 3, product 9 : Introducing Amazon eero Outdoor 7 dual-band mesh wifi system, Weatherproof rating of IP66, Coverage up to 30,000 sq. ft. outdoors, 2-pack, Includes two 30W PoE+ adapters, 2024 release
# no review divs
# Page 3, product 10 : Certified Refurbished Echo Show 15 | Full HD 15.6" smart display with Alexa and Fire TV built in | Remote included
# Review page 1: There are 10 reviews
# Review page 2: There are 10 reviews
# Review page 3: There are 10 reviews
# Review page 4: There are 10 reviews
# Review page 5: There are 10 reviews
# Review page 6: There are 10 reviews
# Review page 7: There are 10 reviews
# Review page 8: There are 10 reviews
# Review page 9: There are 10 reviews
# Review page 10: There are 10 reviews
# Page 3, product
# Review page 1: There are 10 reviews
# Review page 2: There are 10 reviews
# Review page 3: There are 10 reviews
# Review page 4: There are 10 reviews
# Review page 5: There are 10 reviews
# Review page 6: There are 10 reviews
# Review page 7: There are 10 reviews
# Review page 8: There are 10 reviews
# Review page 9: There are 10 reviews
# Review page 10: There are 10 reviews
# Page 4, product 5 : Echo Show 5 (3rd Gen) with Blink Mini | Glacier White
# Review page 1: There are 10 reviews
# Review page 2: There are 10 reviews
# Review page 3: There are 10 reviews
# Review page 4: There are 10 reviews
# Review page 5: There are 10 reviews
# Review page 6: There are 10 reviews
# Review page 7: There are 10 reviews
# Review page 8: There are 10 reviews
# Review page 9: There are 10 reviews
# Review page 10: There are 10 reviews
# Page 4, product 6 : Echo Spot with Energetic Smart Color Bulb
# no review divs
# Page 4, product 7 : Echo Dot (5th Gen) Kids Owl with Echo Glow
# Review page 1: There are 10 reviews
# Review page 2: There are 10 reviews
# Review page 3: There are 10 reviews
# Review page 4: There are 10 reviews
# Review page 5: There are 10 reviews
# Review page 6: There are 10 reviews
# Review page 7: There are 10 reviews
# Review page 8: There are 10 reviews
# Review page 9: There are 10 reviews
# Review page 10: There are 10 reviews
# Page 4, product 8 : Ring Wired Doorbell Pro (Video Doorbell Pro 2) with Ring Floodlight Cam Wired (White) and Ring Alarm 14-Piece (White)
# Review page 1: There are 5 reviews
# no review divs
# Page 4, product 9 : Kindle Essentials Bundle including Kindle (2024 release) - Matcha, Fabric Cover - Matcha, and Power Adapter
# no review divs
# Page 4, product 10 : Ring Pet Tag | Easy-to-use tag with QR code | Real-time scan alerts | Shareable Pet Profile | No subscription or fees | 2-pack
# Review page 1: There are 10 reviews
# Review page 2: There are 10 reviews
# Review page 3: There are 10 reviews
# Review page 4: There are 10 reviews
# Review page 5: There are 10 reviews
# Review page 6: There are 10 reviews
# Review page 7: There are 10 reviews
# Review page 8: There are 10 reviews
# Review page 9: There are 10 reviews
# Review page 10: There are 10 reviews
# Page 4, product 11 : Echo Bundle: Echo Dot (5th Gen, 2022 release) | Charcoal and Limited Edition Marvel Iron Man Stand
# no review divs
# Page 4, product 12 : Ring Pan Tilt Stick Up Cam Plug-In, 1080p HD Plug-In Indoor/Outdoor Camera with 360° Pan-Tilt, Color Night Vision, Live View, Two-way Talk, Built-in Siren, Motion Detection, Works with Alexa, White
# Review page 1: There are 10 reviews
# Review page 2: There are 7 reviews
# no review divs
# Page 4, product 13 : Blink Video Doorbell (Black) + Mini Camera (Black) | Two-Way Audio, HD Video, Motion and Chime Alerts | Works with Alexa
# Review page 1: There are 10 reviews
# Review page 2: There are 10 reviews
# Review page 3: There are 10 reviews
# Review page 4: There are 10 reviews
# Review page 5: There are 10 reviews
# Review page 6: There are 10 reviews
# Review page 7: There are 10 reviews
# Review page 8: There are 10 reviews
# Review page 9: There are 10 reviews
# Review page 10: There are 10 reviews
# Page 4, product 14 : Echo Show 5 with Energetic Smart Color Bulb
# no review divs
# Page 4, product 15 : Blink Weather Resistant 13ft Power Adapter for Blink Mini 2 and Blink Outdoor 4 (Black)
# Review page 1: There are 10 reviews
# Review page 2: There are 10 reviews
# Review page 3: There are 10 reviews
# Review page 4: There are 10 reviews
# Review page 5: There are 10 reviews
# Review page 6: There are 10 reviews
# Review page 7: There are 10 reviews
# Review page 8: There are 10 reviews
# Review page 9: There are 9 reviews
# no review divs
# Page 4, product 16 : Amazon Fire HD 8 Plus tablet, 8” HD Display, 64 GB, 30% faster processor, 3GB RAM, wireless charging, (2022 release), Gray
# Review page 1: There are 10 reviews
# Review page 2: There are 10 reviews
# Review page 3: There are 10 reviews
# Review page 4: There are 10 reviews
# Review page 5: There are 10 reviews
# Review page 6: There are 10 reviews
# Review page 7: There are 10 reviews
# Review page 8: There are 10 reviews
# Review page 9: There are 10 reviews
# Review page 10: There are 10 reviews
# Page 4, product 17 : Ring Wired Doorbell Pro (Video Doorbell Pro 2) with Ring Floodlight Cam Wired (White)
# Review page 1: There are 10 reviews
# Review page 2: There are 10 reviews
# Review page 3: There are 10 reviews
# Review page 4: There are 10 reviews
# Review page 5: There are 10 reviews
# Review page 6: There are 10 reviews
# Review page 7: There are 10 reviews
# Review page 8: There are 10 reviews
# Review page 9: There are 10 reviews
# Review page 10: There are 10 reviews
# Page 4, product 18 : New Amazon Fire HD 8 Tablet (32GB Black, 2024 release) + Standing Cover (Black)
# no review divs
# Page 4, product 19 : Echo Show 5 with TP-Link Tapo 2K Indoor Security Camera
# Review page 1: There are 4 reviews
# no review divs
# Page 4, product 20 : Echo Show 5 (3rd Gen) with Blink Mini | Charcoal
# Review page 1: There are 10 reviews
# Review page 2: There are 10 reviews
# Review page 3: There are 10 reviews
# Review page 4: There are 10 reviews
# Review page 5: There are 9 reviews
# no review divs
# Page 4, product 21 : Echo Show 5 with TP-Link Tapo 2K Indoor Security Camera
# no review divs
# Page 4, product 22 : Amazon Fire TV Omni Series 65" with Fire TV Soundbar
# Review page 1: There are 10 reviews
# Review page 2: There are 10 reviews
# Review page 3: There are 10 reviews
# Review page 4: There are 10 reviews
# Review page 5: There are 10 reviews
# Review page 6: There are 10 reviews
# Review page 7: There are 10 reviews
# Review page 8: There are 10 reviews
# Review page 9: There are 10 reviews
# Review page 10: There are 10 reviews
# Page 4, product 23 : Fire TV Stick with Alexa Voice Remote Bundle. Includes Fire TV Stick with Alexa Voice Remote (includes TV controls), HD streaming device & Made For Amazon USB Power Cable
# Review page 1: There are 10 reviews
# Review page 2: There are 8 reviews
# no review divs
# Page 4, product 24 : Fire HD 8 tablet, 8" HD display, 32 GB, (2020 release), designed for portable entertainment, Black
# Review page 1: There are 10 reviews
# Review page 2: There are 10 reviews
# Review page 3: There are 10 reviews
# Review page 4: There are 10 reviews
# Review page 5: There are 10 reviews
# Review page 6: There are 10 reviews
# Review page 7: There are 10 reviews
# Review page 8: There are 10 reviews
# Review page 9: There are 10 reviews
# Review page 10: There are 10 reviews
# Page 5: https://www.amazon.com/s?i=amazon-devices&rh=n%3A2102313011&s=popularity-rank&fs=true&page=5&qid=1729958028&ref=sr_pg_5
# --> There are: 24 products
# Page 5, product 1 : Fire TV Cube with Alexa Voice Remote Pro
# Review page 1: There are 10 reviews
# Review page 2: There are 10 reviews
# Review page 3: There are 10 reviews
# Review page 4: There are 10 reviews
# Review page 5: There are 10 reviews
# Review page 6: There are 10 reviews
# Review page 7: There are 10 reviews
# Review page 8: There are 10 reviews
# Review page 9: There are 10 reviews
# Review page 10: There are 10 reviews
# Page
# no review divs
# Page 26, product 7 : Amazon Fire Max 11 Bundle with Herschel Classic Backpack and Echo Buds
# no review divs
# Page 26, product 8 : Amazon Fire Max 11 Bundle with Herschel Classic Backpack and Magnetic Cover
# no review divs
# Page 26, product 9 : Amazon Fire 8 Kids tablet, 8" display 32GB (Blue) + Kids Zipper Sleeve (Pink)
# no review divs
# Page 26, product 10 : Echo Show 10 (black) with Sengled Matter Color Bulb
# Review page 1: There are 1 reviews
# no review divs
# Page 26, product 11 : Echo Dot with clock and Sengled Bluetooth Mesh Bulb (1 count)
# no review divs
# Page 26, product 12 : Ring Video Doorbell (Satin Nickel) with Spotlight Cam Pro, Battery White
# Review page 1: There are 1 reviews
# no review divs
# Page 26, product 13 : Echo Show 5 Sandstone with Sengled 2 pack starter kit
# Review page 1: There are 2 reviews
# no review divs
# Page 26, product 14 : Echo Dot + Sengled Bluetooth Mesh Bulb
# no review divs
# Page 26, product 15 : Echo Dot with clock and Sengled Bluetooth Mesh Bulb (1 count)
# no review divs
# Page 26, product 16 : Echo Show 8 (3rd gen) with Sengled Bluetooth Mesh bulb
# no review divs
# Page 26, product 17 : Echo (4th gen) with Sengled Bluetooth Mesh bulb
# no review divs
# Page 26, product 18 : Echo Dot + Sengled Bluetooth Mesh Bulb
# no review divs
# Page 26, product 19 : Echo Show 5 with Sengled Bluetooth Mesh bulb
# no review divs
# Page 26, product 20 : Echo Show 5 with Sengled Bluetooth Mesh Bulb (1 count)
# Review page 1: There are 1 reviews
# no review divs
# Page 26, product 21 : Echo Show 5 with Sengled Bluetooth Mesh bulb
# no review divs
# Page 26, product 22 : Echo Show 5 with Sengled Bluetooth Mesh bulb
# no review divs
# Page 26, product 23 : Echo (4th gen) with Sengled Bluetooth Mesh bulb
# no review divs
# Page 26, product 24 : Churro + Sengled Bluetooth Mesh Bulb
# no review divs
# Page 27: https://www.amazon.com/s?i=amazon-devices&rh=n%3A2102313011&s=popularity-rank&fs=true&page=27&qid=1729958028&ref=sr_pg_27
# --> There are: 24 products
# Page 27, product 1 : Echo (4th gen) with Sengled Bluetooth Mesh bulb
# no review divs
# Page 27, product 2 : Churro + Sengled Bluetooth Mesh Bulb
# no review divs
# Page 27, product 3 : Echo Studio with Sengled Bluetooth Mesh bulb
# no review divs
# Page 27, product 4 : Echo Studio with Sengled Bluetooth Mesh bulb
# no review divs
# Page 27, product 5 : Echo Pop (Lavender Bloom) with Sengled Bluetooth Smart Bulb
# no review divs
# Page 27, product 6 : Echo (4th gen) with Sengled Bluetooth Mesh bulb
# no review divs
# Page 27, product 7 : Echo Dot + Sengled Bluetooth Mesh Bulb
# no review divs
# Page 27, product 8 : Kids Tablet Bundle: Includes Amazon Fire HD 8 Kids tablet |32 GB | Disney Princess & Made for Amazon, Kids Bluetooth Headset Ages (3-7) | Purple
# no review divs
# Page 27, product 9 : Echo Show 8 (2nd Gen) | Glacier White with Sengled Bluetooth Color bulb | Alexa smart home starter kit
# Review page 1: There are 4 reviews
# no review divs
# Page 27, product 10 : All-new Echo Dot (5th Gen, 2022 release) with clock Bundle. Includes Echo Dot (5th Gen, 2022 release) with clock | Cloud Blue & the Made For Amazon Wall Mount | White
# Review page 1: There are 1 reviews
# no review divs
# Page 27, product 11 : Blink Video Doorbell + Sync Module 2 | Two-year battery life, Alexa enabled — wired or wire-free (Black) with Amazon Echo Pop (Charcoal)
# no review divs
# Page 27, product 12 : Blink Outdoor 4 (4th Gen) – Wire-free smart security camera, two-year battery life - 1 camera system with Echo Show 5 - Smart display with 2x the bass and clearer sound | Charcoal
# no review divs
# Page 27, product 13 : Fire 7 Kids Tablet 32GB Purple with Made for Amazon Kids Tablet Backpack, Birds
# Review page 1: There are 1 reviews
# no review divs
# Page 27, product 14 : Fire 7 Kids Edition Tablet + Osmo Genius Kit Bundle (Purple)
# Review page 1: There are 3 reviews
# no review divs
# Page 27, product 15 : Echo Show 5 Bundle: Includes, Echo Show 5 (3rd Gen, 2023 release) | Cloud Blue & Made for Amazon Tilt & Swivel Stand | Glacier White
# no review divs
# Page 27, product 16 : Kids Tablet Bundle: Includes Amazon Fire HD 8 Kids tablet, 8" | 64 GB | Blue & Made for Amazon, Kids Bluetooth Headset Ages (3-7) | Purple
# no review divs
# Page 27, product 17 : AWS Panorama Appliance
# Review page 1: There are 1 reviews
# no review divs
# Page 27, product 18 : Tablet Bundle: Includes Amazon Fire HD 10 tablet, 10.1" (2023 Release) | 32 GB | Lilac & Made for Amazon Clear Case & Stylus Pen
# no review divs
# Page 27, product 19 : Fire HD 10 Tablet with Fire TV Stick
# no review divs
# Page 27, product 20 : Tablet Bundle: Includes Amazon Fire HD 10 tablet, 10.1" (2023 Release) | 64 GB | Black & Made for Amazon Clear Case & Stylus Pen
# no review divs
# Page 27, product 21 : Tablet Bundle: Includes Amazon Fire HD 10 tablet, 10.1" (2023 Release) | 32 GB | Ocean & Made for Amazon Clear Case & Stylus Pen
# no review divs
# Page 27, product 22 : Alexa Voice Remote Pro with Made for Amazon Active Noise Cancelling Bluetooth Headset | Good Grey
# no review divs
# Page 27, product 23 : Fire HD 8 Smart Home Bundle including Fire HD 8 Tablet 64 GB Without Ads (Black) with Blink Mini Camera
# no review divs
# Page 27, product 24 : Alexa Voice Remote Pro with Made for Amazon Active Noise Cancelling Bluetooth Headset | Black
# no review divs
# Page 28: https://www.amazon.com/s?i=amazon-devices&rh=n%3A2102313011&s=popularity-rank&fs=true&page=28&qid=1729958028&ref=sr_pg_28
# --> There are: 24 products
# Page 28, product 1 : Echo Show 8 Bundle: Includes, Echo Show 8 (3rd Gen, 2023 release) | Charcoal and Made for Amazon Battery Base | Charcoal
# no review divs
# Page 28, product 2 : Blink Outdoor 4 (4th Gen) + Battery Extension Pack — Four-year battery wire-free smart security camera, two-way audio, HD live view, enhanced motion detection — 6 camera system
# no review divs
# Page 28, product 3 : Echo Show 8 (3rd Gen, 2023 release) bundle with Amazon Basics Smart Color Bulb
# Review page 1: There are 10 reviews
# Review page 2: There are 4 reviews
# no review divs
# Page 28, product 4 : Amazon Alexa Voice Remote Pro Bundle: Includes, Amazon Alexa Voice Remote Pro | Black, and Made for Amazon Remote Cover Case | Glow in the Dark
# no review divs
# Page 28, product 5 : Echo Show 8 (3rd Gen, 2023 release) in Charcoal bundle with Philips Hue Smart Color Bulb
# no review divs
# Page 28, product 6 : Tablet Bundle for Amazon Fire HD 10, (13th Gen, 2023 release). Included: Made for Amazon Clear Case and Stylus Pen
# no review divs
# Page 28, product 7 : Tablet Bundle for Amazon Fire HD 10, (13th Gen, 2023 release). Included: Made for Amazon Clear Case, Stylus Pen and NuPro Antiglare Screen Protector
# no review divs
# Page 28, product 8 : Tablet Bundle: Includes Amazon Fire HD 10 tablet, 10.1" (2023 Release) |
# no review divs
# Page 29, product 3 : Echo Show 5 (Sandstone) Bundle with Senged 2-pack smart bulb starter kit
# no review divs
# Page 29, product 4 : Echo Dot Bundle: Includes Echo Dot (5th Gen, 2022 release) | Glacier White and Limited Edition Disney Jack Skellington Shell
# Review page 1: There are 10 reviews
# Review page 2: There are 3 reviews
# no review divs
# Page 29, product 5 : Echo Show 5 (2nd Gen, 2021 release) | Smart display with Alexa and 2 MP camera | Charcoal
# Review page 1: There are 10 reviews
# Review page 2: There are 10 reviews
# Review page 3: There are 10 reviews
# Review page 4: There are 10 reviews
# Review page 5: There are 10 reviews
# Review page 6: There are 10 reviews
# Review page 7: There are 10 reviews
# Review page 8: There are 10 reviews
# Review page 9: There are 10 reviews
# Review page 10: There are 10 reviews
# Page 29, product 6 : Certified Refurbished Fire TV Cube (2nd Gen), Hands-free streaming device with Alexa, 4K Ultra HD, includes 1-Year SquareTrade Warranty
# Review page 1: There are 10 reviews
# Review page 2: There are 10 reviews
# Review page 3: There are 3 reviews
# no review divs
# Page 29, product 7 : Echo Plus with built-in Hub 1st Generation– White
# Review page 1: There are 10 reviews
# Review page 2: There are 10 reviews
# Review page 3: There are 10 reviews
# Review page 4: There are 10 reviews
# Review page 5: There are 10 reviews
# Review page 6: There are 10 reviews
# Review page 7: There are 10 reviews
# Review page 8: There are 10 reviews
# Review page 9: There are 10 reviews
# Review page 10: There are 10 reviews
# Page 29, product 8 : Certified Refurbished Fire HD 10 tablet, 10.1" display, 32GB (Black, 2021 release) + Amazon Standing Cover
# Review page 1: There are 10 reviews
# Review page 2: There are 10 reviews
# Review page 3: There are 10 reviews
# Review page 4: There are 10 reviews
# Review page 5: There are 10 reviews
# Review page 6: There are 10 reviews
# Review page 7: There are 10 reviews
# Review page 8: There are 10 reviews
# Review page 9: There are 10 reviews
# Review page 10: There are 10 reviews
# Page 29, product 9 : Kindle Paperwhite 3G, 6" High-Resolution Display (300 ppi) with Built-in Light, Free 3G + Wi-Fi (International Version, Previous Generation - 7th)
# Review page 1: There are 10 reviews
# Review page 2: There are 10 reviews
# Review page 3: There are 10 reviews
# Review page 4: There are 10 reviews
# Review page 5: There are 10 reviews
# Review page 6: There are 10 reviews
# Review page 7: There are 10 reviews
# Review page 8: There are 10 reviews
# Review page 9: There are 10 reviews
# Review page 10: There are 7 reviews
# Page 29, product 10 : Echo (4th Gen) | Glacier White with Philips Hue Color Smart Bulb
# no review divs
# Page 29, product 11 : Echo Dot (4th Gen) International Version - Smart speaker with Alexa - Charcoal with Sengled Bluetooth Color bulb
# no review divs
# Page 29, product 12 : Echo (4th Gen) | Charcoal with Philips Hue Color Smart Bulb
# no review divs
# Page 29, product 13 : Echo (4th Gen) | Twilight Blue with Philips Hue Color Smart Bulb
# no review divs
# Page 29, product 14 : Echo Studio | Glacier White with Philips Hue Color Smart Bulb
# no review divs
# Page 29, product 15 : Echo Studio | Charcoal with Philips Hue Color Smart Bulb
# no review divs
# Page 29, product 16 : Fire 7 Tablet 2-pack (7" display, 16 GB) - Black & Twilight Blue
# no review divs
# Page 29, product 17 : Fire HD 8 Tablet 2-pack | 10.1" 1080p Full HD Display, 16 GB, Black & Blue
# no review divs
# Page 29, product 18 : All-new Echo Dot (3rd Gen) - Charcoal + Sengled 4 Bulb Kit
# no review divs

# %%
# Empty List to Hold all reviews data
reviews = []

# Iterate all Html pages 
for html_data in html_datas:
    
    # Grab review data
    review = getReviews(html_data)
    
    # add review data in reviews empty list
    reviews += review

# %%
# Create a dataframe with reviews Data
df_reviews = pd.DataFrame(reviews)

# %%
df_reviews
# Out:
#             Review_id              Reviewer Rating        Date  \
# 0      R192QJ45JRSLTC                 Chris    5.0  13/07/2024
# 1       RLJN0G2I0CRNC       Amazon Customer    5.0  12/10/2024
# 2      R19D78F9YK0DVA       uniquely unique    5.0  11/10/2024
# 3      R2W7QUYHDCN6CB  Lyndi Dawn Macdonald    4.0  26/09/2024
# 4       RM9R0N4N310DC            ccoulson90    5.0  21/10/2024
# ...               ...                   ...    ...         ...
# 15857  R3M2LG3W8S0EKR               A. Rose    2.0  20/12/2018
# 15858   RMFF5NVA9YK87       Kindle Customer    2.0  26/01/2016
# 15859  R11DMWR29QKLWY                Gordon    4.0  11/05/2016
# 15860  R1PCPXC0B5ZUNC           dorothyinoz    1.0  12/05/2016
# 15861  R1Z35MJOPXC2F1       Viacheslav Land    5.0  01/01/2019
#
#                                           Review title  \
# 0      Didn't think I needed it until I wish I had it.
# 1                                   Worth every penny!
# 2                                  I’m quite satisfied
# 3                             Very Nice Added Security
# 4                                           Great Item
# ...                                                ...
# 15857        Cannot Change Reading Progress Font Sizes
# 15858                                   New paperwhite
# 15859                              Kindle Great Device
# 15860                                DEFECTIVE PRODUCT
# 15861                            Best Paperwhite Ever!
#
#                                           Review content  Product_id  \
# 0      The Blink Subscription Basic Plan offers essen...  B08JHCVHTY
# 1      I have had Blink cameras at my house for years...  B08JHCVHTY
# 2      I’ve been using the Blink Subscription Plus Pl...  B08JHCVHTY
# 3      Really like having these cameras, they give us...  B08JHCVHTY
# 4      The Blink Subscription Plus Plan is a fantasti...  B08JHCVHTY
# ...                                                  ...         ...
# 15857  Just wasted half an hour on the phone with tec...  B00QJDVBFU
# 15858  Why would I buy this I like to listen to music...  B00QJDVBFU
# 15859  I am in my eighties and find it quite intuitiv...  B00QJDVBFU
# 15860  Within six months of buying this product it fa...  B00QJDVBFU
# 15861              The more I use it the more I like it!  B00QJDVBFU
#
#                                            Product_title  \
# 0      Blink Subscription Plus Plan with monthly auto...
# 1      Blink Subscription Plus Plan with monthly auto...
# 2      Blink Subscription Plus Plan with monthly auto...
# 3      Blink Subscription Plus Plan with monthly auto...
# 4      Blink Subscription Plus Plan with monthly auto...
# ...                                                  ...
# 15857  Kindle Paperwhite 3G, 6" High-Resolution Displ...
# 15858  Kindle Paperwhite 3G, 6" High-Resolution Displ...
# 15859  Kindle Paperwhite 3G, 6" High-Resolution Displ...
# 15860  Kindle Paperwhite 3G, 6" High-Resolution Displ...
# 15861  Kindle Paperwhite 3G, 6" High-Resolution Displ...
#
#                                             Product_link
# 0      https://www.amazon.com/Blink-Plus-Plan-monthly...
# 1      https://www.amazon.com/Blink-Plus-Plan-monthly...
# 2      https://www.amazon.com/Blink-Plus-Plan-monthly...
# 3      https://www.amazon.com/Blink-Plus-Plan-monthly...
# 4      https://www.amazon.com/Blink-Plus-Plan-monthly...
# ...                                                  ...
# 15857  https://www.amazon.com/Paperwhite-High-Resolut...
# 15858  https://www.amazon.com/Paperwhite-High-Resolut...
# 15859  https://www.amazon.com/Paperwhite-High-Resolut...
# 15860  https://www.amazon.com/Paperwhite-High-Resolut...
# 15861  https://www.amazon.com/Paperwhite-High-Resolut...
#
# [15862 rows x 9 columns]

# %% [markdown]
# ## <font color="red">5. Dataset Export</font>

# %%
# Export data to an Excel file
df_reviews.to_excel('amazon_reviews.xlsx', index=False)
